# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("D:/datasets/credit_train.csv")
df1 = pd.read_csv("D:/datasets/credit_test.csv")

# %%
df.head()
# Out:
#                                 Loan ID                           Customer ID  \
# 0  14dd8831-6af5-400b-83ec-68e61888a048  981165ec-3274-42f5-a3b4-d104041a9ca9
# 1  4771cc26-131a-45db-b5aa-537ea4ba5342  2de017a3-2e01-49cb-a581-08169e83be29
# 2  4eed4e6a-aa2f-4c91-8651-ce984ee8fb26  5efb2b2b-bf11-4dfd-a572-3761a2694725
# 3  77598f7b-32e7-4e3b-a6e5-06ba0d98fe8a  e777faab-98ae-45af-9a86-7ce5b33b1011
# 4  d4062e70-befa-4995-8643-a0de73938182  81536ad9-5ccf-4eb8-befb-47a4d608658e
#
#   Loan Status  Current Loan Amount        Term  Credit Score  Annual Income  \
# 0  Fully Paid             445412.0  Short Term         709.0      1167493.0
# 1  Fully Paid             262328.0  Short Term           NaN            NaN
# 2  Fully Paid           99999999.0  Short Term         741.0      2231892.0
# 3  Fully Paid             347666.0   Long Term         721.0       806949.0
# 4  Fully Paid             176220.0  Short Term           NaN            NaN
#
# ...

# %%
df = df.drop(['Loan ID','Customer ID'],axis=1)

# %%
df.head()
# Out:
#   Loan Status  Current Loan Amount        Term  Credit Score  Annual Income  \
# 0  Fully Paid             445412.0  Short Term         709.0      1167493.0
# 1  Fully Paid             262328.0  Short Term           NaN            NaN
# 2  Fully Paid           99999999.0  Short Term         741.0      2231892.0
# 3  Fully Paid             347666.0   Long Term         721.0       806949.0
# 4  Fully Paid             176220.0  Short Term           NaN            NaN
#
#   Years in current job Home Ownership             Purpose  Monthly Debt  \
# 0              8 years  Home Mortgage   Home Improvements       5214.74
# 1            10+ years  Home Mortgage  Debt Consolidation      33295.98
# 2              8 years       Own Home  Debt Consolidation      29200.53
# 3              3 years       Own Home  Debt Consolidation       8741.90
# 4              5 years           Rent  Debt Consolidation      20639.70
#
#    Years of Credit History  Months since last delinquent  \
# ...

# %%
len(df)
# Out:
# 100514

# %%
df= df.drop_duplicates()

# %%
len(df)
# Out:
# 89786

# %%
import seaborn as sns

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
for i in range(len(df.columns)):
    x = df.columns[i]
    if ' ' in x:
        y = x.replace(' ','_')
        df = df.rename(columns={x:y})

# %%
df[(df['Term']=='Short Term') & (df['Loan_Status']=='Fully Paid')]
# Out:
#       Loan_Status  Current_Loan_Amount        Term  Credit_Score  \
# 0      Fully Paid             445412.0  Short Term         709.0
# 1      Fully Paid             262328.0  Short Term           NaN
# 2      Fully Paid           99999999.0  Short Term         741.0
# 4      Fully Paid             176220.0  Short Term           NaN
# 6      Fully Paid             217646.0  Short Term         730.0
# 8      Fully Paid             548746.0  Short Term         678.0
# 9      Fully Paid             215952.0  Short Term         739.0
# 10     Fully Paid           99999999.0  Short Term         728.0
# 11     Fully Paid             541970.0  Short Term           NaN
# 12     Fully Paid           99999999.0  Short Term         740.0
# 13     Fully Paid           99999999.0  Short Term         743.0
# 14     Fully Paid             234124.0  Short Term         727.0
# 18     Fully Paid              66396.0  Short Term           NaN
# ...

# %%
import matplotlib.pyplot as plt

# %%
sns.barplot(x='Bankruptcies',y='Loan_Status',data=df)

# %%
df[df['Months_since_last_delinquent'].isnull()==True]
# Out:
#         Loan_Status  Current_Loan_Amount        Term  Credit_Score  \
# 0        Fully Paid             445412.0  Short Term         709.0
# 3        Fully Paid             347666.0   Long Term         721.0
# 4        Fully Paid             176220.0  Short Term           NaN
# 5       Charged Off             206602.0  Short Term        7290.0
# 9        Fully Paid             215952.0  Short Term         739.0
# 11       Fully Paid             541970.0  Short Term           NaN
# 13       Fully Paid           99999999.0  Short Term         743.0
# 15       Fully Paid             449020.0   Long Term           NaN
# 16      Charged Off             653004.0   Long Term           NaN
# 18       Fully Paid              66396.0  Short Term           NaN
# 19       Fully Paid             390390.0  Short Term         747.0
# 21       Fully Paid             128238.0  Short Term         750.0
# 22      Charged Off             153252.0  Short Term         714.0
# ...

# %%
df.Years_in_current_job.unique()
# Out:
# array([ 8., 10.,  3.,  5.,  0.,  2.,  4.,  9.,  7.,  1.,  6.])

# %%
df.head()
# Out:
#   Loan_Status  Current_Loan_Amount        Term  Credit_Score  Annual_Income  \
# 0  Fully Paid             445412.0  Short Term         709.0      1167493.0
# 1  Fully Paid             262328.0  Short Term           NaN            NaN
# 2  Fully Paid           99999999.0  Short Term         741.0      2231892.0
# 3  Fully Paid             347666.0   Long Term         721.0       806949.0
# 4  Fully Paid             176220.0  Short Term           NaN            NaN
#
#   Years_in_current_job Home_Ownership             Purpose  Monthly_Debt  \
# 0           Fully Paid  Home Mortgage   Home Improvements       5214.74
# 1           Fully Paid  Home Mortgage  Debt Consolidation      33295.98
# 2           Fully Paid       Own Home  Debt Consolidation      29200.53
# 3           Fully Paid       Own Home  Debt Consolidation       8741.90
# 4           Fully Paid           Rent  Debt Consolidation      20639.70
#
#    Years_of_Credit_History  Months_since_last_delinquent  \
# ...

# %%
df = df.dropna(subset=['Years_in_current_job'])

# %%
df['Years_in_current_job'] = df.Years_in_current_job.map({'< 1 year':0,'1 year':1,'2 years':2,'3 years':3,'4 years':4,'5 years':5,'6 years':6,'7 years':7,'8 years':8,'9 years':9,'10+ years':10})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-70-0a1ef04c6da7> in <module>()
# ----> 1 len(df['Years in current job']==nan)
#
# NameError: name 'nan' is not defined

# %%
from sklearn.preprocessing import LabelEncoder,OneHotEncoder

# %%
df.head()
# Out:
#   Loan_Status  Current_Loan_Amount        Term  Credit_Score  Annual_Income  \
# 0  Fully Paid             445412.0  Short Term         709.0      1167493.0
# 1  Fully Paid             262328.0  Short Term           NaN            NaN
# 2  Fully Paid           99999999.0  Short Term         741.0      2231892.0
# 3  Fully Paid             347666.0   Long Term         721.0       806949.0
# 4  Fully Paid             176220.0  Short Term           NaN            NaN
#
#   Years_in_current_job Home_Ownership             Purpose  Monthly_Debt  \
# 0              8 years  Home Mortgage   Home Improvements       5214.74
# 1            10+ years  Home Mortgage  Debt Consolidation      33295.98
# 2              8 years       Own Home  Debt Consolidation      29200.53
# 3              3 years       Own Home  Debt Consolidation       8741.90
# 4              5 years           Rent  Debt Consolidation      20639.70
#
#    Years_of_Credit_History  Months_since_last_delinquent  \
# ...

# %%
df.Term.unique()
# Out:
# array(['Short Term', 'Long Term', nan], dtype=object)

# %%
df['Term'] = df.Term.map({'Short Term':0,'Long Term':1})

# %%
sns.barplot(y='Annual_Income',x='Loan_Status',data=df)

# %%
len(df[(df['Annual_Income']>500000) & (df['Loan_Status']=='Fully Paid')])
# Out:
# 51231

# %%
df[df['Annual_income']>50000]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# E:\progfiles\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Annual_income'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-61-6df5d47de9b4> in <module>()
# ----> 1 df[df['Annual_income']>50000]
#
# ...

# %%
df.Loan_Status.unique()
# Out:
# array(['Fully Paid', 'Charged Off'], dtype=object)

# %%
labelEnco = LabelEncoder()

# %%
df['Term'] = labelEnco.fit_transform(df.iloc[:,2])

# %%
df.Years_in_current_job.isnull
# Out:
# <bound method Series.isnull of 0          8 years
# 1        10+ years
# 2          8 years
# 3          3 years
# 4          5 years
# 5        10+ years
# 6         < 1 year
# 7         < 1 year
# 8          2 years
# 9         < 1 year
# 10         3 years
# 11       10+ years
# 12        < 1 year
# 13         4 years
# 14       10+ years
# 15         9 years
# 16         7 years
# 17       10+ years
# 18       10+ years
# 19         8 years
# 20         8 years
# 21        < 1 year
# 22         2 years
# 23       10+ years
# 24         4 years
# 25         3 years
# 26          1 year
# 27         2 years
# 28       10+ years
# 29             NaN
#            ...
# 99958      2 years
# 99960      5 years
# 99963          NaN
# 99964    10+ years
# 99966      7 years
# 99968    10+ years
# 99970     < 1 year
# 99971      8 years
# 99972      5 years
# 99974    10+ years
# 99975    10+ years
# 99976    10+ years
# 99977    10+ years
# 99978    10+ years
# 99979      7 years
# ...

# %%
# Out:
# 89785

# %%
df.drop(df[89785:],axis=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-94-89e3efaf333e> in <module>()
# ----> 1 df.drop(df[89785:],axis=0)
#
# E:\progfiles\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3692                                            index=index, columns=columns,
#    3693                                            level=level, inplace=inplace,
# -> 3694                                            errors=errors)
#    3695
#    3696     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# E:\progfiles\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3106         for axis, labels in axes.items():
#    3107             if labels is not None:
# -> 3108                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# ...

# %%
df = df.dropna(subset = ['Term'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 89785 entries, 0 to 99999
# Data columns (total 17 columns):
# Loan_Status                     89785 non-null object
# Current_Loan_Amount             89785 non-null float64
# Term                            89785 non-null object
# Credit_Score                    70631 non-null float64
# Annual_Income                   70631 non-null float64
# Years_in_current_job            85983 non-null object
# Home_Ownership                  89785 non-null object
# Purpose                         89785 non-null object
# Monthly_Debt                    89785 non-null float64
# Years_of_Credit_History         89785 non-null float64
# Months_since_last_delinquent    41448 non-null float64
# Number_of_Open_Accounts         89785 non-null float64
# Number_of_Credit_Problems       89785 non-null float64
# Current_Credit_Balance          89785 non-null float64
# Maximum_Open_Credit             89783 non-null float64
# ...

# %%
df.head()
# Out:
#   Loan_Status  Current_Loan_Amount        Term  Credit_Score  Annual_Income  \
# 0  Fully Paid             445412.0  Short Term         709.0      1167493.0
# 1  Fully Paid             262328.0  Short Term           NaN            NaN
# 2  Fully Paid           99999999.0  Short Term         741.0      2231892.0
# 3  Fully Paid             347666.0   Long Term         721.0       806949.0
# 4  Fully Paid             176220.0  Short Term           NaN            NaN
#
#   Years_in_current_job Home_Ownership             Purpose  Monthly_Debt  \
# 0              8 years  Home Mortgage   Home Improvements       5214.74
# 1            10+ years  Home Mortgage  Debt Consolidation      33295.98
# 2              8 years       Own Home  Debt Consolidation      29200.53
# 3              3 years       Own Home  Debt Consolidation       8741.90
# 4              5 years           Rent  Debt Consolidation      20639.70
#
#    Years_of_Credit_History  Months_since_last_delinquent  \
# ...

# %%
ltr = pd.read_csv('D:\datasets\Ltr.csv')

# %%
ltr.head()
# Out:
#    Loan_Status  Current_Loan_Amount  Term  Annual_Income  \
# 0            1             445412.0     0              2
# 1            1             262328.0     0              2
# 2            1           99999999.0     0              3
# 3            1             347666.0     1              1
# 4            1             176220.0     0              1
#
#    Years_in_current_job  Home_Ownership  Purpose  Monthly_Debt  \
# 0                   8.0               0        1       5214.74
# 1                  10.0               0        0      33295.98
# 2                   8.0               2        0      29200.53
# 3                   3.0               2        0       8741.90
# 4                   5.0               1        0      20639.70
#
#    Years_of_Credit_History  Number_of_Open_Accounts  \
# 0                     17.2                      6.0
# 1                     21.1                     35.0
# 2                     14.9                     18.0
# ...

# %%
x=ltr.drop('Loan_Status',axis=1)

# %%
y=ltr[['Loan_Status']]

# %%
# Out:
# pandas.core.frame.DataFrame

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.30)

# %%
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.fit_transform(x_test)

# %%
# Out:
# array([[-3.81379838e-01, -6.08284129e-01,  1.26531443e+00, ...,
#         -1.27530072e-01, -1.89967938e-02, -3.24971567e-01],
#        [-3.86743356e-01, -6.08284129e-01,  3.03710690e-01, ...,
#          4.32406837e-01,  1.62628053e-03, -3.24971567e-01],
#        [-3.86484086e-01, -6.08284129e-01, -6.57893047e-01, ...,
#         -2.37223410e-01, -6.06363917e-02, -3.24971567e-01],
#        ...,
#        [-3.86967001e-01,  1.64396859e+00,  1.26531443e+00, ...,
#         -1.86684333e-01,  2.29781601e-02, -3.24971567e-01],
#        [-3.91104760e-01, -6.08284129e-01, -6.57893047e-01, ...,
#         -3.27282142e-01, -6.49300049e-02, -3.24971567e-01],
#        [-3.86715648e-01, -6.08284129e-01,  3.03710690e-01, ...,
#         -6.37676881e-02, -4.97676883e-02, -3.24971567e-01]])

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
classifier = Sequential()

# %%
classifier.add(Dense(units=7,init='uniform' , activation='relu' , input_dim=13))
# Out:
# E:\progfiles\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(units=7, activation="relu", input_dim=13, kernel_initializer="uniform")`
#   """Entry point for launching an IPython kernel.

# %%
classifier.add(Dense(units=7 , init='uniform' , activation = 'relu'))
# Out:
# E:\progfiles\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(units=7, activation="relu", kernel_initializer="uniform")`
#   """Entry point for launching an IPython kernel.

# %%
classifier.add(Dense(units=7 , init='uniform' , activation = 'relu'))
# Out:
# E:\progfiles\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(units=7, activation="relu", kernel_initializer="uniform")`
#   """Entry point for launching an IPython kernel.

# %%
classifier.add(Dense(units=7 , init='uniform' , activation = 'relu'))
# Out:
# E:\progfiles\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(units=7, activation="relu", kernel_initializer="uniform")`
#   """Entry point for launching an IPython kernel.

# %%
classifier.add(Dense(units=7 , init='uniform' , activation = 'relu'))
# Out:
# E:\progfiles\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(units=7, activation="relu", kernel_initializer="uniform")`
#   """Entry point for launching an IPython kernel.

# %%
classifier.add(Dense(units=7 , init='uniform' , activation = 'relu'))
# Out:
# E:\progfiles\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(units=7, activation="relu", kernel_initializer="uniform")`
#   """Entry point for launching an IPython kernel.

# %%
classifier.add(Dense(output_dim = 1, init = 'uniform' , activation='sigmoid'))
# Out:
# E:\progfiles\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="sigmoid", units=1, kernel_initializer="uniform")`
#   """Entry point for launching an IPython kernel.

# %%
classifier.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
classifier.fit(x_train,y_train,batch_size=10,nb_epoch = 30)
# Out:
# E:\progfiles\lib\site-packages\ipykernel_launcher.py:1: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   """Entry point for launching an IPython kernel.
# Epoch 1/30
# 60053/60053 [==============================] - 93s 2ms/step - loss: 0.5647 - accuracy: 0.7516
# Epoch 2/30
# 60053/60053 [==============================] - 88s 1ms/step - loss: 0.5608 - accuracy: 0.7517A: 29s -  - ETA: 28s - loss: 0.5600 - accuracy: 0.752 - ETA: 28 - ETA: 26s - loss - ETA: 24s - loss: 0.5592 - accura - ETA: 24s - loss: 0.5595  - ETA: 23s - loss: 0.5597 - accuracy: - ETA: 22
# Epoch 3/30
# 60053/60053 [==============================] - 83s 1ms/step - loss: 0.5608 - accuracy: 0.7517
# Epoch 4/30
# 60053/60053 [==============================] - 87s 1ms/step - loss: 0.5608 - accuracy: 0.7517 0s - loss: 0.560
# Epoch 5/30
# ...
