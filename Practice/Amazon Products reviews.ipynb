# %%
import pandas as pd
x = input()
from selenium.webdriver.common.by import By
import time
from selenium import webdriver
import pymysql
path = 'C:\Program Files (x86)\chromedriver.exe'
driver = webdriver.Chrome(path)
time.sleep(2)
driver.get("https://www.amazon.in")
time.sleep(0.8)
search = driver.find_element_by_id('twotabsearchtextbox')
search.send_keys(x)
search.submit()
try:
    driver.find_elements(By.TAG_NAME,'h2')[0].click()
    time.sleep(0.9)
    driver.switch_to_window(driver.window_handles[2])
except:
    time.sleep(0.4)
    driver.find_elements(By.TAG_NAME,'h2')[0].click()
    time.sleep(0.9)
    driver.switch_to_window(driver.window_handles[2])
allrev = driver.find_elements(By.LINK_TEXT,'See all reviews')[0].click()
prod = []
for i in range(3):
    time.sleep(2)
    r1 = driver.find_elements(By.CLASS_NAME,'review')
    prod.extend([(i.text) for i in r1])
    time.sleep(0.9)
    driver.find_element_by_class_name('a-last').click()
names=[]
titles=[]
reviews = []
review_date = []
prod_desc = []
for i in prod:
    names.append(i.splitlines()[0])
    titles.append(i.splitlines()[1])
    reviews.append(i.splitlines()[4:-3][0])
    review_date.append(i.splitlines()[2])
    prod_desc.append(i.splitlines()[3])
rev = {'name':names,'title':titles}
revdata = pd.DataFrame(rev)
z2 = list(map(list, zip(names,titles,reviews,review_date,prod_desc)))
#--------------------SQL Connection------------------------------------------------------
db = pymysql.connect('localhost','root','redhat','testdb')
cursor = db.cursor()
cursor.execute('select version()')
#--------------------Inserting values-----------------------------------------------------
with db.cursor() as cursor:
    cursor.executemany("insert into product1(c_name,r_title,review,reviewed_date,product_description) values (%s,%s,%s,%s,%s)", z2 )
    db.commit()
# Out:
# iphone 11
# E:\progfiles\lib\site-packages\ipykernel_launcher.py:17: DeprecationWarning: use driver.switch_to.window instead

# %%
from selenium.webdriver.common.by import By
import time
from selenium import webdriver
import pymysql
path = 'C:\Program Files (x86)\chromedriver.exe'
driver = webdriver.Chrome(path)
time.sleep(2)
driver.get("https://www.amazon.in")
time.sleep(0.8)

#--------------------------------Search Box -----------------------------------#

search = driver.find_element_by_id('twotabsearchtextbox')
search.send_keys('mobiles')
search.submit()

dis = driver.find_elements(By.CLASS_NAME,'a-disabled')

n = int(dis[1].text)
prod_name = []


#==============================All Products-General=====================================#

for i in range(n):
    time.sleep(1.3)
    a = driver.find_elements(By.TAG_NAME,'h2')
    for j in a:
        prod_name.append(j)
#=============================Single-Product-Review-Storing====================#


driver.get("https://www.amazon.in")
time.sleep(0.8)
search = driver.find_element_by_id('twotabsearchtextbox')
search.send_keys(x)
search.submit()
try:
    driver.find_elements(By.TAG_NAME,'h2')[0].click()
    time.sleep(0.9)
    driver.switch_to_window(driver.window_handles[2])
except:
    time.sleep(0.4)
    driver.find_elements(By.TAG_NAME,'h2')[0].click()
    time.sleep(0.9)
    driver.switch_to_window(driver.window_handles[2])
allrev = driver.find_elements(By.LINK_TEXT,'See all reviews')[0].click()
prod = []


#--------- Next page For Review--and-break------------------#

dri = ['']
while True:
    
    if driver.current_url!=dri[0]:
        try:
            time.sleep()
            r1 = driver.find_elements(By.CLASS_NAME,'review')
              # adding the text to prod
            prod.extend([(i.text) for i in r1])
            time.sleep(0.9)
            dri[0] = driver.current_url
            driver.find_element_by_class_name('a-last').click()
            print(dri)
        except:
            print('-----------------------------------------------------------------------------------')
            time.sleep(2)
            r1 = driver.find_elements(By.CLASS_NAME,'review')
            prod.extend([(i.text) for i in r1])
            time.sleep(0.9)
            dri[0] = driver.current_url
            driver.find_element_by_class_name('a-last').click()
            print(dri)
            pass
            
    else: 
        break
        
        
#----------------------Split-and-Assign---------------------------# 
names=[]
titles=[]
reviews = []
review_date = []
prod_desc = []
for i in prod:
    names.append(i.splitlines()[0])
    titles.append(i.splitlines()[1])
    reviews.append(i.splitlines()[4:-3][0])
    review_date.append(i.splitlines()[2])
    prod_desc.append(i.splitlines()[3])
rev = {'name':names,'title':titles}
revdata = pd.DataFrame(rev)
z2 = list(map(list, zip(names,titles,reviews,review_date,prod_desc)))
#--------------------SQL Connection------------------------------------------------------
db = pymysql.connect('localhost','root','redhat','testdb')
cursor = db.cursor()
cursor.execute('select version()')
#--------------------Inserting values-----------------------------------------------------
with db.cursor() as cursor:
    cursor.executemany("insert into product1(c_name,r_title,review,reviewed_date,product_description) values (%s,%s,%s,%s,%s)", z2 )
    db.commit()

# %%
#___________________PRESENT__Stage________________________________
from selenium.webdriver.common.by import By
import time
from selenium import webdriver
import pymysql
path = 'C:\Program Files (x86)\chromedriver.exe'
driver = webdriver.Chrome(path)
time.sleep(2)
driver.get("https://www.amazon.in")
time.sleep(0.8)

#--------------------------------Search Box -----------------------------------#

search = driver.find_element_by_id('twotabsearchtextbox')
search.send_keys('mobiles')
search.submit()

dis = driver.find_elements(By.CLASS_NAME,'a-disabled')

n = int(dis[1].text)
prod_name = []


#==============================All Products-General=====================================#

for i in range(n):
    time.sleep(1.3)
    a = driver.find_elements(By.TAG_NAME,'h2')
    for j in a:
        if 'Stand' not in j.text and len(j.text)>20 and '(' in j.text:
            prod_name.append(j.text)
        else:
            pass
    driver.find_element_by_class_name('a-last').click()
#==================================Specific=========================================================

for z in range(5):
    driver.get("https://www.amazon.in")
    time.sleep(0.8)
    search = driver.find_element_by_id('twotabsearchtextbox')
    search.send_keys(prod_name[z])
    search.submit()
    try:
        driver.find_elements(By.TAG_NAME,'h2')[0].click()
        time.sleep(0.9)
        driver.switch_to_window(driver.window_handles[-1])
    except:
        time.sleep(0.4)
        driver.find_elements(By.TAG_NAME,'h2')[0].click()
        time.sleep(0.9)
        driver.switch_to_window(driver.window_handles[-1])
    try:
        try:
            
            allrev = driver.find_elements(By.LINK_TEXT,'See all reviews')[0].click()
        except:
            for k in range(2):
                allrev = driver.find_elements(By.LINK_TEXT,'See all reviews')[0].click()
                
    except:
        time.sleep(0.4)
        driver.find_elements(By.TAG_NAME,'h2')[0].click()
        time.sleep(0.9)
        driver.switch_to_window(driver.window_handles[-1])
        allrev = driver.find_elements(By.LINK_TEXT,'See all reviews')[0].click()
    prod = []
    #---------------------total reviews-----------------------------
    
    
    tot_rev=[]
    tot_rev.append(driver.find_elements(By.CLASS_NAME,'a-spacing-base')[1].text.split(' ')[-3])
    if tot_rev.count(driver.find_elements(By.CLASS_NAME,'a-spacing-base')[1].text.split(' ')[-3])>1:
        break

#--------- Next page For Review--and-break------------------#

    dri = ['']
    
    while True:
        
        if driver.current_url!=dri[0]:
            try:
                time.sleep(2)
                r1 = driver.find_elements(By.CLASS_NAME,'review')
                  # adding the text to prod
                prod.extend([(i.text) for i in r1])
                time.sleep(0.9)
                dri[0] = driver.current_url
                driver.find_element_by_class_name('a-last').click()
                print(dri)
            except:
                try:
                    print('--------------------------------Stale-Element-Exception-----------------------------')
                    time.sleep(2)
                    r1 = driver.find_elements(By.CLASS_NAME,'review')
                    prod.extend([(i.text) for i in r1])
                    time.sleep(0.9)
                    dri[0] = driver.current_url
                    driver.find_element_by_class_name('a-last').click()
                    print(dri)
                    pass
                except:
                    if driver.find_elements(By.CLASS_NAME,'a-spacing-base')[1].text.split(' ')[-3]==0:
                        pass
            
        else: 
            break
    
    
    #----------------------Split-and-Assign---------------------------# 
    names=[]
    titles=[]
    reviews = []
    review_date = []
    prod_desc = []
    prod_n = []
    for i in prod:
        try:
            names.append(i.splitlines()[0])
            titles.append(i.splitlines()[1])
            reviews.append(i.splitlines()[4:-3][0])
            review_date.append(i.splitlines()[2])
            prod_desc.append(i.splitlines()[3])
            prod_n.append(prod_name[z])
        except IndexError:
            try:    
                
                names.append(i.splitlines()[0])
                titles.append(i.splitlines()[1])
                #reviews.append(i.splitlines()[4:-3][0])
                review_date.append(i.splitlines()[2])
                prod_desc.append(i.splitlines()[3])
                prod_n.append(prod_name[z])
            except:
                pass
    rev = {'name':names,'title':titles}

    z2 = list(map(list, zip(names,titles,reviews,review_date,prod_desc,prod_n)))
    
    #--------------------------------------SQL Connection------------------------------------------------------
    db = pymysql.connect('localhost','root','redhat','testdb')
    cursor = db.cursor()
    cursor.execute('select version()')
    #-------------------------------------Inserting values-----------------------------------------------------
    with db.cursor() as cursor:
        cursor.executemany("insert into product(c_name,r_title,review,reviewed_date,product_description,Product_Name) values (%s,%s,%s,%s,%s,%s)", z2 )
        db.commit()
# Out:
# E:\progfiles\lib\site-packages\ipykernel_launcher.py:46: DeprecationWarning: use driver.switch_to.window instead
# ['https://www.amazon.in/Apple-iPhone-11-128GB-Black/product-reviews/B07XVLW7YK/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews']
# ['https://www.amazon.in/Apple-iPhone-11-128GB-Black/product-reviews/B07XVLW7YK/ref=cm_cr_arp_d_paging_btm_next_2?ie=UTF8&reviewerType=all_reviews&pageNumber=2']
# ['https://www.amazon.in/Apple-iPhone-11-128GB-Black/product-reviews/B07XVLW7YK/ref=cm_cr_getr_d_paging_btm_next_3?ie=UTF8&reviewerType=all_reviews&pageNumber=3']
# ['https://www.amazon.in/Apple-iPhone-11-128GB-Black/product-reviews/B07XVLW7YK/ref=cm_cr_getr_d_paging_btm_next_4?ie=UTF8&reviewerType=all_reviews&pageNumber=4']
# ['https://www.amazon.in/Apple-iPhone-11-128GB-Black/product-reviews/B07XVLW7YK/ref=cm_cr_getr_d_paging_btm_next_5?ie=UTF8&reviewerType=all_reviews&pageNumber=5']
# ...

# %%
pip install scrapy
# Out:
# ...
#
# ...
#   Created wheel for protego: filename=Protego-0.1.16-py3-none-any.whl size=7769 sha256=09422477b0f9f7530612ee13dbd0b373b21dee927b2907348da98dd7f12770fc
#   Stored in directory: c:\users\mohdu\appdata\local\pip\cache\wheels\b2\74\25\517a0ec6186297704db56664268e72686f5cfa8ab398582f33
# ...
#   Created wheel for PyDispatcher: filename=PyDispatcher-2.0.5-py3-none-any.whl size=12552 sha256=9da93bb6874177c16cfe75ae939436f19dd0f6aa5958486cec72aef734bab043
#   Stored in directory: c:\users\mohdu\appdata\local\pip\cache\wheels\28\db\61\691c759da06ba9b86da079bdd17cb3e01828d49d5c152cb3af
# Successfully built protego PyDispatcher
# ...

# %%
k=0
from selenium.webdriver.common.by import By
import time
from selenium import webdriver
import pymysql
path = 'C:\Program Files (x86)\chromedriver.exe'
driver = webdriver.Chrome(path)
time.sleep(2)
driver.get("https://www.amazon.in")
time.sleep(0.8)

#--------------------------------Search Box -----------------------------------#

search = driver.find_element_by_id('twotabsearchtextbox')
search.send_keys('mobiles')
search.submit()

dis = driver.find_elements(By.CLASS_NAME,'a-disabled')

n = int(dis[1].text)
prod_name = []


#==============================All Products-General=====================================#

for i in range(n):
    time.sleep(1.3)
    a = driver.find_elements(By.TAG_NAME,'h2')
    for j in a:
        if 'Stand' not in j.text and len(j.text)>20 and '(' in j.text:
            prod_name.append(j.text)
        else:
            pass
    driver.find_element_by_class_name('a-last').click()

    
#---------------------------------------------------------------------------------------------##
for z in range(5):
    driver.get("https://www.amazon.in")
    time.sleep(0.8)
    search = driver.find_element_by_id('twotabsearchtextbox')
    search.send_keys(prod_name[z])
    search.submit()
    try:
        driver.find_elements(By.TAG_NAME,'h2')[0].click()
        time.sleep(0.9)
        driver.switch_to_window(driver.window_handles[-1])
    except:
        time.sleep(0.4)
        driver.find_elements(By.TAG_NAME,'h2')[0].click()
        time.sleep(0.9)
        driver.switch_to_window(driver.window_handles[-1])
    try:
        try:
            allrev = driver.find_elements(By.LINK_TEXT,'See all reviews')[0].click()
        except:
            try:
                driver.close()
                time.sleep(1.2)
                driver = webdriver.Chrome(path)
                for z in range(5):
                    driver.get("https://www.amazon.in")
                    time.sleep(0.8)
                    search = driver.find_element_by_id('twotabsearchtextbox')
                    search.send_keys(prod_name[z])
                    search.submit()
                    try:
                        driver.find_elements(By.TAG_NAME,'h2')[0].click()
                        time.sleep(0.9)
                        driver.switch_to_window(driver.window_handles[-1])
                    except:
                        time.sleep(0.4)
                        driver.find_elements(By.TAG_NAME,'h2')[0].click()
                        time.sleep(0.9)
                        driver.switch_to_window(driver.window_handles[-1])
                        allrev = driver.find_elements(By.LINK_TEXT,'See all reviews')[0].click()
            except:
                k=1
        
                
                pass
    if k==1:
        pass
    else:
        print(' ')
                
    except:
        time.sleep(0.4)
        driver.find_elements(By.TAG_NAME,'h2')[0].click()
        time.sleep(0.9)
        driver.switch_to_window(driver.window_handles[-1])
        allrev = driver.find_elements(By.LINK_TEXT,'See all reviews')[0].click()
    prod = []
    #---------------------total reviews-----------------------------
    
    
    tot_rev=[]
    tot_rev.append(driver.find_elements(By.CLASS_NAME,'a-spacing-base')[1].text.split(' ')[-3])
    if tot_rev.count(driver.find_elements(By.CLASS_NAME,'a-spacing-base')[1].text.split(' ')[-3])>1:
        break

#--------- Next page For Review--and-break------------------#

    dri = ['']
    
    while True:
        
        if driver.current_url!=dri[0]:
            try:
                time.sleep(2)
                r1 = driver.find_elements(By.CLASS_NAME,'review')
                  # adding the text to prod
                prod.extend([(i.text) for i in r1])
                time.sleep(0.9)
                dri[0] = driver.current_url
                driver.find_element_by_class_name('a-last').click()
                print(dri)
            except:
                try:
                    print('--------------------------------Stale-Element-Exception-----------------------------')
                    time.sleep(2)
                    r1 = driver.find_elements(By.CLASS_NAME,'review')
                    prod.extend([(i.text) for i in r1])
                    time.sleep(0.9)
                    dri[0] = driver.current_url
                    driver.find_element_by_class_name('a-last').click()
                    print(dri)
                    pass
                except:
                    if driver.find_elements(By.CLASS_NAME,'a-spacing-base')[1].text.split(' ')[-3]==0:
                        pass
            
        else: 
            break
    
    
    #----------------------Split-and-Assign---------------------------# 
    names=[]
    titles=[]
    reviews = []
    review_date = []
    prod_desc = []
    prod_n = []
    for i in prod:
        try:
            names.append(i.splitlines()[0])
            titles.append(i.splitlines()[1])
            reviews.append(i.splitlines()[4:-3][0])
            review_date.append(i.splitlines()[2])
            prod_desc.append(i.splitlines()[3])
            prod_n.append(prod_name[z])
        except IndexError:
            try:    
                
                names.append(i.splitlines()[0])
                titles.append(i.splitlines()[1])
                #reviews.append(i.splitlines()[4:-3][0])
                review_date.append(i.splitlines()[2])
                prod_desc.append(i.splitlines()[3])
                prod_n.append(prod_name[z])
            except:
                pass
    rev = {'name':names,'title':titles}

    z2 = list(map(list, zip(names,titles,reviews,review_date,prod_desc,prod_n)))
    
    #--------------------------------------SQL Connection------------------------------------------------------
    db = pymysql.connect('localhost','root','redhat','testdb')
    cursor = db.cursor()
    cursor.execute('select version()')
    #-------------------------------------Inserting values-----------------------------------------------------
    with db.cursor() as cursor:
        cursor.executemany("insert into product(c_name,r_title,review,reviewed_date,product_description,Product_Name) values (%s,%s,%s,%s,%s,%s)", z2 )
        db.commit()
# Out:
#   File "<ipython-input-34-da323a856d9d>", line 82
#     if k==1:
#      ^
# SyntaxError: invalid syntax

# %%
driver.find_elements(By.TAG_NAME,'h2')[2].click()

# %%
time.sleep(0.4)
driver.find_elements(By.TAG_NAME,'h2')[0].click()
time.sleep(0.9)
driver.switch_to_window(driver.window_handles[-1])
# Out:
# E:\progfiles\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: use driver.switch_to.window instead
#   after removing the cwd from sys.path.

# %%
print(driver.find_elements(By.CLASS_NAME,'a-spacing-base')[1].text.split(' ')[-3])
# Out:
# 0

# %%
driver.find_elements(By.TAG_NAME,'s-image')
# Out:
# []

# %%
driver.current_url
# Out:
# 'https://www.amazon.in/s?k=Samsung+Galaxy+M31+%28Ocean+Blue%2C+6GB+RAM%2C+128GB+Storage%29&ref=nb_sb_noss'

# %%
names=[]
titles=[]
reviews = []
review_date = []
prod_desc = []
prod_n = []
for i in prod:
    try:
        
        names.append(i.splitlines()[0])
        titles.append(i.splitlines()[1])
        reviews.append(i.splitlines()[4:-3][0])
        review_date.append(i.splitlines()[2])
        try:
            prod_desc.append(i.splitlines()[3])
        except:
            print('NOOO')
        prod_n.append(prod_name[z])
    except IndexError:
        
        try:
                
            names.append(i.splitlines()[0])
            titles.append(i.splitlines()[1])
            #reviews.append(i.splitlines()[4:-3][0])
            review_date.append(i.splitlines()[2])
            try:
                prod_desc.append(i.splitlines()[3])
            except:
                print('NO')
            prod_n.append(prod_name[z])
        except:
            pass
rev = {'name':names,'title':titles}
revdata = pd.DataFrame(rev)
z2 = list(map(list, zip(names,titles,reviews,review_date,prod_desc,prod_n)))
    
    #--------------------SQL Connection------------------------------------------------------
db = pymysql.connect('localhost','root','redhat','testdb')
cursor = db.cursor()
cursor.execute('select version()')
    #--------------------Inserting values-----------------------------------------------------
with db.cursor() as cursor:
    cursor.executemany("insert into product1(c_name,r_title,review,reviewed_date,product_description,Product_Name) values (%s,%s,%s,%s,%s,%s)", z2 )
    db.commit()
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-58-41d66ffd4116> in <module>
#      42     #--------------------Inserting values-----------------------------------------------------
#      43 with db.cursor() as cursor:
# ---> 44     cursor.executemany("insert into product1(c_name,r_title,review,reviewed_date,product_description,Product_Name) values (%s,%s,%s,%s,%s,%s)", z2 )
#      45     db.commit()
#
# E:\progfiles\lib\site-packages\pymysql\cursors.py in executemany(self, query, args)
#     195             return self._do_execute_many(q_prefix, q_values, q_postfix, args,
#     196                                          self.max_stmt_length,
# --> 197                                          self._get_db().encoding)
#     198
#     199         self.rowcount = sum(self.execute(query, arg) for arg in args)
#
# ...

# %%
cursor.close()

# %%
prod[123].splitlines()[4:-3]
# Out:
# ['Here’s my long term review on IPhone 11 64GB. I had ordered this phone around 7months back and this has been my daily driver since then. To give you a perspective I am using the dual sim in here reliance Jio as esim and Vodafone idea as physical sim. Both works fine and network connectivity is great.',
#  'WiFi reception is Average I would say.',
#  'Call quality is awesome one can hear clean and crisp',
#  'The speaker is Loud and the music plays great I love it',
#  'The display is good but not great like my Old Note 9, but still colour reproduction is accurate',
#  'Battery back up is good and it typically lasts a whole day.',
#  'The phone is slippery so I use a back case.',
#  'Nothing more to say about i0S and it’s updates they are great']

# %%
try:
    driver.find_elements(By.TAG_NAME,'h2')[0].click()
    time.sleep(0.9)
    driver.switch_to_window(driver.window_handles[2])
except:
    time.sleep(0.4)
    driver.find_elements(By.TAG_NAME,'h2')[0].click()
    time.sleep(0.9)
    driver.switch_to_window(driver.window_handles[2])
# Out:
# E:\progfiles\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: use driver.switch_to.window instead
#   after removing the cwd from sys.path.

# %%
allrev = driver.find_elements(By.LINK_TEXT,'See all reviews')[0].click()

# %%
page1 = driver.current_url

# %%
#--------- Next page For Review--and-break------------------#



dri = ['']
while True:
    
    if driver.current_url!=dri[0]:
        try:
            time.sleep()
            r1 = driver.find_elements(By.CLASS_NAME,'review')
              # adding the text to prod
            prod.extend([(i.text) for i in r1])
            time.sleep(0.9)
            dri[0] = driver.current_url
            driver.find_element_by_class_name('a-last').click()
            print(dri)
        except:
            print('-----------------------------------------------------------------------------------')
            time.sleep(2)
            r1 = driver.find_elements(By.CLASS_NAME,'review')
          
            prod.extend([(i.text) for i in r1])
            time.sleep(0.9)
            dri[0] = driver.current_url
            driver.find_element_by_class_name('a-last').click()
            print(dri)
            pass
            
    else: 
        break
for z in pro
# Out:
# ['https://www.amazon.in/Apple-iPhone-11-128GB-Black/product-reviews/B07XVLW7YK/ref=cm_cr_getr_d_paging_btm_next_296?ie=UTF8&reviewerType=all_reviews&pageNumber=296']

# %%
len(prod)
# Out:
# 3022

# %%
prod = []
for i in range(3):
    time.sleep(2)
    r1 = driver.find_elements(By.CLASS_NAME,'review')
    prod.extend([(i.text) for i in r1])
    time.sleep(0.9)
    driver.find_element_by_class_name('a-last').click()
names=[]
titles=[]
reviews = []
review_date = []
prod_desc = []
for i in prod:
    names.append(i.splitlines()[0])
    titles.append(i.splitlines()[1])
    reviews.append(i.splitlines()[4:-3][0])
    review_date.append(i.splitlines()[2])
    prod_desc.append(i.splitlines()[3])
rev = {'name':names,'title':titles}
revdata = pd.DataFrame(rev)
z2 = list(map(list, zip(names,titles,reviews,review_date,prod_desc)))
#--------------------SQL Connection------------------------------------------------------
db = pymysql.connect('localhost','root','redhat','testdb')
cursor = db.cursor()
cursor.execute('select version()')
#--------------------Inserting values-----------------------------------------------------
with db.cursor() as cursor:
    cursor.executemany("insert into product1(c_name,r_title,review,reviewed_date,product_description) values (%s,%s,%s,%s,%s)", z2 )
    db.commit()

# %%
dis = driver.find_elements(By.CLASS_NAME,'a-disabled')

# %%
int(dis[1].text)
# Out:
# 20

# %%
#Drop table

import pymysql
db = pymysql.connect('localhost','root','redhat','testdb')
cursor = db.cursor()
cursor.execute('select version()')
cursor.execute('drop table if exists product')
cursor.close()

# %%
names=[]
titles=[]
reviews = []
review_date = []
prod_desc = []
for i in prod:
    names.append(i.splitlines()[0])
    titles.append(i.splitlines()[1])
    reviews.append(i.splitlines()[4:-3][0])
    review_date.append(i.splitlines()[2])
    prod_desc.append(i.splitlines()[3])

# %%
reviews
# Out:
# ["May be my first negative review about the product & Amazon both. I was much elated to receive the iPhone 11 so fast, next day of dispatch i.e. 28/09/19, but the thing I got started heating up every now and then. Contacted Applecare, just to be consoled that it's quite normal. As it continued, tried to return the product by speaking to Amazon customer support but in vain. Some body called me back to convey that only Apple will decide which one to take back. Why is then Amazon took up the sacred duty of selling such an item which they can't exchange/ have no control ? The product developed new issues like proximity sensor malfunction and last but most importantly loosing mobile network every other minute(even had two software updates). It was handed over to the Apple ASP as the return window closed on 10/10/19 (what use it was for??) and diagnosed as having issues and has further been sent to Apple repair facility at Bengaluru. So I'm here w/out my first iPhone after using it(sufferi
# ...

# %%
#CREATE Query
#create table product(c_id int NOT NULL AUTO_INCREMENT,c_name varchar(80) NOT NULL ,r_title varchar(200) NOT NULL,review varchar(2000) NOT NULL, reviewed_date varchar(100),product_description varchar(200),Product_Name varchar(150),primary key(c_id));
# Out:
# ['Awesome Phone. Nice upgrade from iPhone 6s to iPhone 11. Love this beautiful phone.']

# %%
# import Tokenizer
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
tokenizer = Tokenizer(num_words=100,oov_token="<OOV>")
tokenizer.fit_on_texts(prod)
word_index = tokenizer.word_index
sequences = tokenizer.texts_to_sequences(prod)
padded = pad_sequences(sequences,padding='post')

# %%
from keras.models import model_from_json
json_file = open('model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights("model.h5")
print("Loaded model from disk")
# Out:
# Loaded model from disk

# %%
pred = loaded_model.predict(padded)
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x00000248EDBAF598> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x00000248EDBAF598> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert

# %%
min(pred)
# Out:
# array([0.55073863], dtype=float32)

# %%
pred
# Out:
# array([[0.55150545],
#        [0.55073875],
#        [0.55074984],
#        [0.5507403 ],
#        [0.5507399 ],
#        [0.5507393 ],
#        [0.83992076],
#        [0.55074155],
#        [0.5507394 ],
#        [0.5507388 ],
#        [0.5507388 ],
#        [0.5507389 ],
#        [0.5507655 ],
#        [0.55073863],
#        [0.5507391 ],
#        [0.5507553 ],
#        [0.55074173],
#        [0.55073917],
#        [0.55073875],
#        [0.5507403 ],
#        [0.5507395 ],
#        [0.55074054],
#        [0.5507406 ],
#        [0.550739  ],
#        [0.550739  ],
#        [0.55073977],
#        [0.5507389 ],
#        [0.5507388 ],
#        [0.5507389 ],
#        [0.5507388 ]], dtype=float32)

# %%
re = driver.find_elements(By.CLASS_NAME,"a-section")

# %%
for i in re:
    print(i.text)
# Out:
# 1-16 of over 2,000 results for "panasonic"
# Sort by:
#
#             Featured
#
#             Price: Low to High
#
#             Price: High to Low
#
#             Avg. Customer Review
#
#             Newest Arrivals
#
#     Sort by:Featured
# Panasonic Lithium Coin Batteries / Various Sizes
# Shop Panasonic Batteries India
# Panasonic CR-2032/5BE Lithium Coin Battery - Pack of 5
# 4,295
# Panasonic CR-2025/5BE Lithium Coin Battery - Pack of 5
# 4,295
# Panasonic CR 1616-5BE Lithium Coin Battery - Pack of 5
# 4,295
# Sponsored
# Panasonic Eluga I8 (Black, 3GB RAM, 32GB Storage)
# 331
# ₹8,138
# ₹14,990 Save ₹6,852 (46%)
# Save extra with No Cost EMI
# Get it by Monday, October 5
# FREE Delivery by Amazon
# More Buying Choices
# ₹8,097 (6 new offers)
#
#
#
# Panasonic Eluga I8 (Black, 3GB RAM, 32GB Storage)
# 331
# ₹8,138
# ₹14,990 Save ₹6,852 (46%)
# Save extra with No Cost EMI
# Get it by Monday, October 5
# FREE Delivery by Amazon
# More Buying Choices
# ₹8,097 (6 new offers)
#
#
# ...

# %%
products[6].text
# Out:
# ''

# %%
print(products[20].text)
# Out:
# Samsung Galaxy M21 (Raven Black, 6GB RAM, 128GB Storage)

# %%
Products=[]
while True:
    time.sleep(4)
    products = driver.find_elements(By.TAG_NAME,'h2').text
    print(products)
    Products.extend(products)
    time.sleep(4)
    next_page = driver.find_element_by_class_name('a-last')
    next_page.click()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-531f1b24b04b> in <module>
#       2 while True:
#       3     time.sleep(4)
# ----> 4     products = driver.find_elements(By.TAG_NAME,'h2').text
#       5     print(products)
#       6     Products.extend(products)
#
# AttributeError: 'list' object has no attribute 'text'

# %%
driver.close()

# %%
len(products)
# Out:
# 17

# %%
for i in Products:
    print(i)
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="18a2f27f077aff1836fcee74a6c26d2a", element="1a6498cc-72c9-4ec6-adeb-04be62b701a1")>
# <selenium.webdriver.remote.webelement.WebElement (session="18a2f27f077aff1836fcee74a6c26d2a", element="6d10bfe5-bc1c-4e86-ab3e-f1bae06c8a72")>
# <selenium.webdriver.remote.webelement.WebElement (session="18a2f27f077aff1836fcee74a6c26d2a", element="0483714c-b8c1-4e5e-9b0d-22d5698f70db")>
# <selenium.webdriver.remote.webelement.WebElement (session="18a2f27f077aff1836fcee74a6c26d2a", element="22be2820-161b-4520-b09b-0a1ba1160d3d")>
# <selenium.webdriver.remote.webelement.WebElement (session="18a2f27f077aff1836fcee74a6c26d2a", element="b2aeba39-b4b9-4cc8-b44d-4fd1189d7b82")>
# <selenium.webdriver.remote.webelement.WebElement (session="18a2f27f077aff1836fcee74a6c26d2a", element="a154f2af-66d0-40e3-8e69-5e764e0f7294")>
# ...

# %%
rev = driver.find_elements(By.TAG_NAME,"span")

# %%
len(rev)
# Out:
# 940

# %%
rr = driver.find_elements(By.CLASS_NAME,'a-link-emphasis')

# %%
driver.find_element_by_partial_link_text('See').click()

# %%
driver.current_url
# Out:
# 'https://www.amazon.in/s?k=panasonic&ref=nb_sb_noss_1'

# %%
rr[0].text
# Out:
# ''

# %%
driver.current_url
# Out:
# 'https://www.amazon.in/s?k=panasonic&ref=nb_sb_noss_1'

# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
cont = requests.get(driver.current_url).content

# %%
beau = BeautifulSoup(cont)

# %%
beau.findAll(attrs={'data-hook':'see-all-reviews-link-foot'})
# Out:
# []

# %%
pip install numpy dlib
# Out:
# ...
#   ERROR: Command errored out with exit status 1:
#    command: 'E:\progfiles\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\mohdu\\AppData\\Local\\Temp\\pip-install-rapbbsay\\dlib\\setup.py'"'"'; __file__='"'"'C:\\Users\\mohdu\\AppData\\Local\\Temp\\pip-install-rapbbsay\\dlib\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\mohdu\AppData\Local\Temp\pip-wheel-m7ctwyvq'
#        cwd: C:\Users\mohdu\AppData\Local\Temp\pip-install-rapbbsay\dlib\
#   Complete output (53 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   package init file 'tools\python\dlib\__init__.py' not found (or not a regular file)
#   running build_ext
#   Traceback (most recent call last):
#     File "C:\Users\mohdu\AppData\Local\Temp\pip-install-rapbbsay\dlib\setup.py", line 120, in get_cmake_version
# ...

# %%
from selenium import webdriver

# %%
driver = webdriver.Chrome('C:\Program Files (x86)\Google\Chrome\Application\chrome.exe')
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-42-6f8e10288d20> in <module>
# ----> 1 driver = webdriver.Chrome('C:\Program Files (x86)\Google\Chrome\Application\chrome.exe')
#
# E:\progfiles\lib\site-packages\selenium\webdriver\chrome\webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, keep_alive)
#      71             service_args=service_args,
#      72             log_path=service_log_path)
# ---> 73         self.service.start()
#      74
#      75         try:
#
# E:\progfiles\lib\site-packages\selenium\webdriver\common\service.py in start(self)
#      96         count = 0
#      97         while True:
# ---> 98             self.assert_process_still_running()
#      99             if self.is_connectable():
#     100                 break
#
# ...

# %%
driver.get('https://dfaanalytics.com')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-f8eac780e952> in <module>
# ----> 1 driver.get('https://dfaanalytics.com')
#
# AttributeError: module 'selenium.webdriver.chrome' has no attribute 'get'

# %%
pip install keyboard
